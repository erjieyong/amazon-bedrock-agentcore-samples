# %% [markdown]
# # Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# ## Overview
#
# In this Lab, you will learn how to integrate tools available in your organization with the Customer Support Agent using the Amazon Bedrock Gateway.
#
# The [Model Context Protocol (MCP)](https://modelcontextprotocol.io/docs/getting-started/intro) is an open protocol that standardizes how applications provide tools and context to Large Language Models (LLMs).
#
# With [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html), developers can convert APIs, Lambda functions, and existing services into MCP-compatible tools and make them available to agents through Gateway endpoints with just a few lines of code.
#
#
# **Workshop Journey:**
#
# - **Lab 1 (Done):** Create Agent Prototype - Built a functional customer support agent
# - **Lab 2 (Done):** Enhance with Memory - Added conversation context and personalization
# - **Lab 3 (Current):** Scale with Gateway & Identity - Shared tools across agents securely
# - **Lab 4:** Deploy to Production - Used AgentCore Runtime with observability
# - **Lab 5:** Evaluate Agent Performance - Monitor quality with online evaluations
# - **Lab 6:** Build User Interface - Create a customer-facing application
#
#
# ### Why AgentCore Gateway & Tool Sharing Matter
#
# Current State (Lab 1-2): Each agent has its own copy of tools. A practice that is not scalable and leads to:
#
# - Code duplication across different agents
# - Inconsistent tool behavior and maintenance overhead
# - No centralized security or access control
# - Difficulty scaling to multiple use cases
#
# After this lab, we will have centralized, reusable tools that can serve:
#
# - Customer Support Agent (our current use case)
# - Sales Agent (needs same product info and customer data)
# - Inventory Agent (needs same product info and warranty checking)
# - Returns Processing Agent (needs return policies and customer profiles)
#
# and other use cases.
#
# ### Adding secure authentication with AgentCore Identity
#
# Additionally, AgentCore Gateway requires you to securely authenticate both inbound and outbound connections. [AgentCore Identity](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/identity.html) provides seamless agent identity and access management across AWS services and third-party applications such as Slack and Zoom while supporting any standard identity providers such as Okta, Entra, and Amazon Cognito. In this lab we will see how AgentCore Gateway integrates with AgentCore Identity to provide secure connections via inbound and outbound authentication.
#
# For the inbound authentication, the AgentCore Gateway analyzes the OAuth token passed during invocation to decide allow or deny the access to a tool in the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
# During the inbound authorization flow, an agent or the MCP client calls an MCP tool in the AgentCore Gateway adding an OAuth access token (generated from the user’s IdP). AgentCore Gateway then validates the OAuth access token and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, OAuth will retrieve credentials of downstream resources using the resource credential provider for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.
#
#
# ## Architecture for Lab 3
#
# <div style="text-align:left">
#     <img src="images/architecture_lab3_gateway.png" width="75%"/>
# </div>
#
# *Web search tool is now centralized in AgentCore Gateway with secure identity-based access control. Multiple agents and use cases can share the same tool securely. We will also reuse the `check_warranty()` tool built for other applications and add the `web_search()` tool for use within other applications. `get_product_info()`, `get_return_policy()`, and `get_technical_support` remain as local tools as they are specific to the customer support use case*
#
# ### Key Features
# - **Seamlessly integrate AWS Lambda functions:** This example shows how to integrate your Agent with existing AWS Lambda functions to check the warranty of an item and to get the customer profile using Amazon Bedrock AgentCore Gateway.
# - **Secure your Gateway endpoint with Inbound Auth**: Only an Agent providing a valid JWT token can connect to the endpoint to use the tools
# - **Configure the Agent to use the MCP endpoint**: The Agent gets a valid JWT token and uses it to connect to the MCP endpoint provided by AgentCore Gateway
#
# ## Prerequisites
#
# * Python 3.12+
# * AWS credentials configured
# * Anthropic Claude 3.7 enabled on [Amazon Bedrock](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
# * Complete Lab 2 Add memory to the Customer Support Agent
# * These resources are created for you within an AWS workshop account
#     - AWS Lambda function
#     - AWS Lambda Execution IAM Role
#     - AgentCore Gateway IAM Role
#     - DynamoDB tables used by the AWS Lambda function.
#     - Cognito User Pool and User Pool Client

# %% [markdown]
# ## Step 1: Import required libraries

# %%
# Import libraries
import os
import sys
import boto3

from strands import Agent
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from mcp.client.streamable_http import streamablehttp_client
from lab_helpers.utils import (
    get_or_create_cognito_pool,
    put_ssm_parameter,
    get_ssm_parameter,
    load_api_spec,
)


sts_client = boto3.client("sts")

# Get AWS account details
REGION = boto3.session.Session().region_name

gateway_client = boto3.client(
    "bedrock-agentcore-control",
    region_name=REGION,
)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## Step 2: Give our agent a tool to access existing customer data
# AgentCore Gateway simplifies agent tool integration in three key ways:
#
# Universal MCP Support: Instantly make your tools compatible with any agent framework by exposing them through AgentCore Gateway's MCP standard
#
# Simple REST Integration: Transform existing REST services into agent tools by just adding them as AgentCore Gateway targets
#
# Lambda Flexibility: Expose Lambda functions as MCP endpoints that can call any API - demonstrated here with a function that checks warranty status
#
# AgentCore Gateway populates the Lambda context with the name of the tool to invoke, while the parameters passed to the tool are provided in the Lambda event:
#
# ```
# extended_tool_name = context.client_context.custom["bedrockAgentCoreToolName"]
# resource = extended_tool_name.split("___")[1]
# ```
#
# [Lambda function](./prerequisite/lambda/python/lambda_function.py)
#
# ```
# def lambda_handler(event, context):
#     if get_tool_name(event) == "check_warranty_status":
#         serial_number = get_named_parameter(event=event, name="serial_number")
#         customer_email = get_named_parameter(event=event, name="customer_email")
#
#         warranty_status = check_warranty_status(serial_number, customer_email)
#         return {"statusCode": 200, "body": warranty_status}
# ```

# %% [markdown]
# ## Step 3 Convert your web search tool to MCP
# Now that we are developing an MCP server using AgentCore Gateway, we can MCP-ify any tools which we think we'll use for multiple Agents. One of these tools might be a web search tool like we built in Lab1. As a result, we also converted the web search tool from Lab 1 into a Lambda tool within our AgentCore Gateway:
#
# [Web search Lambda](./prerequisite/lambda/python/web_search.py)
# ```
# from ddgs import DDGS
#
#
# def web_search(keywords: str, region: str = "us-en", max_results: int = 5) -> str:
#     """Search the web for updated information.
#
#     Args:
#         keywords (str): The search query keywords.
#         region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc.
#         max_results (int): The maximum number of results to return.
#
#     Returns:
#         List of dictionaries with search results.
#     """
#     try:
#         results = DDGS().text(keywords, region=region, max_results=max_results)
#         return results if results else "No results found."
#     except Exception as e:
#         return f"Search error: {str(e)}"
#
#
# print("✅ Web search tool ready")
# ```

# %% [markdown]
# ## Step 4 Create your function definition metadata
# Lastly, we need to write tool schema which describes the tools implemented by your Lambda function.
#
# This file has been already defined in [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json)
#
# ```
# [
#     {
#         "name": "check_warranty_status",
#         "description": "Check the warranty status of a product using its serial number and optionally verify via email",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "serial_number": {
#                     "type": "string"
#                 },
#                 "customer_email": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "serial_number"
#             ]
#         }
#     },
#     {
#         "name": "web_search",
#         "description": "Search the web for updated information using DuckDuckGo",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "keywords": {
#                     "type": "string",
#                     "description": "The search query keywords"
#                 },
#                 "region": {
#                     "type": "string",
#                     "description": "The search region (e.g., us-en, uk-en, ru-ru)"
#                 },
#                 "max_results": {
#                     "type": "integer",
#                     "description": "The maximum number of results to return"
#                 }
#             },
#             "required": [
#                 "keywords"
#             ]
#         }
#     }
# ]
# ```

# %% [markdown]
# ## Step 5. Create your AgentCore Gateway
#
# Now let's create the AgentCore Gateway to expose the Lambda function as MCP-compatible endpoint.
#
# To validate the callers authorized to invoke our tools we need to configure the Inbound Auth.
#
# Inbound Auth works using OAuth authorization, the standard for MCP servers. With OAuth the client application must authenticate with the OAuth authorizer before using the Gateway. Your client would receive an access token which is used at runtime.
#
# You need to specify an OAuth discovery server and client IDs. The Cloudformation provided with the workshop already provisioned the Cognito UserPool and UserPoolClient and it stored the discovery URL and the Client ID in dedicated SSM parameters.

# %%
get_or_create_cognito_pool(refresh_token=True)
# Out:
# {'pool_id': 'ap-southeast-1_vtJZmYDUg',
#  'client_id': 'eo2ak4kga0glbdgujt8ogfrvg',
#  'client_secret': '13262gfe41mu456cb4t0i4uh0g2qe73cgj3gnml3cv87th9pm3uq',
#  'secret_hash': 'u1gDx8WHuoJD61dp+ivMVOEDfSt/vaRSltny3U6qCPY=',
#  'bearer_token': 'eyJraWQiOiJMTnVJbWp6eW9uVlZOd0ttMnZNQ3pSVUxrQkZZTmV5VE03WWdkUjNpbTQwPSIsImFsZyI6IlJTMjU2In0.....A-3MbCUUt4ddSXkW9lBGVP9KTnqZ4I2y8dSngmTzLt69K5gz4L7Q6x8hhvJBD5ylZgfd59xusDnQP3gVbPEAN8tRk4BoGwwbig2EwKz_9LciqKJrpJRNsqQK51fI8mBBgzMRMMwTbxC-ofggG8i9NX6yNorCY9jOnWZjuymABZY4SO2sS0UYY_riGZ7RBZp5iVVu0fakQKh1KolHLNEIeO0I8a_CIQ0e_EDQG0NT6nv7Vz2ffClnW-G4Ql8CgZ_DbFkxaquHIpsnAC1_Mds83WDP1hL2VcdbID0xTMe5-jKYOrOLUZqEwTM9UJs8aE3XV4977ze5C6kCEK-g3e89Iw',
#  'discovery_url': 'https://cognito-idp.ap-southeast-1.amazonaws.com/ap-southeast-1_vtJZmYDUg/.well-known/openid-configuration'}

# %%
gateway_name = "customersupport-gw"

cognito_config = get_or_create_cognito_pool(refresh_token=True)
auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [cognito_config["client_id"]],
        "discoveryUrl": cognito_config["discovery_url"],
    }
}

try:
    # create new gateway
    print(f"Creating gateway in region {REGION} with name: {gateway_name}")

    create_response = gateway_client.create_gateway(
        name=gateway_name,
        roleArn=get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role"),
        protocolType="MCP",
        authorizerType="CUSTOM_JWT",
        authorizerConfiguration=auth_config,
        description="Customer Support AgentCore Gateway",
    )

    gateway_id = create_response["gatewayId"]

    gateway = {
        "id": gateway_id,
        "name": gateway_name,
        "gateway_url": create_response["gatewayUrl"],
        "gateway_arn": create_response["gatewayArn"],
    }
    put_ssm_parameter("/app/customersupport/agentcore/gateway_id", gateway_id)
    put_ssm_parameter("/app/customersupport/agentcore/gateway_name", gateway_name)
    put_ssm_parameter(
        "/app/customersupport/agentcore/gateway_arn", create_response["gatewayArn"]
    )
    put_ssm_parameter(
        "/app/customersupport/agentcore/gateway_url", create_response["gatewayUrl"]
    )
    print(f"✅ Gateway created successfully with ID: {gateway_id}")

except Exception:
    # If gateway exists, collect existing gateway ID from SSM
    existing_gateway_id = get_ssm_parameter("/app/customersupport/agentcore/gateway_id")
    print(f"Found existing gateway with ID: {existing_gateway_id}")

    # Get existing gateway details
    gateway_response = gateway_client.get_gateway(gatewayIdentifier=existing_gateway_id)
    gateway = {
        "id": existing_gateway_id,
        "name": gateway_response["name"],
        "gateway_url": gateway_response["gatewayUrl"],
        "gateway_arn": gateway_response["gatewayArn"],
    }
    gateway_id = gateway["id"]
# Out:
# Creating gateway in region ap-southeast-1 with name: customersupport-gw
# Found existing gateway with ID: customersupport-gw-mnyzzral2q

# %% [markdown]
# ## Step 6. Add the Lambda function Target
# Now we will use the previously defined function definitions from [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json) to create a Lambda target within our Agent Gateway. This will define the tools that your gateway will host.
#
# Gateway allows you to attach multiple targets to a Gateway and you can change the targets / tools attached to a gateway at any point. Each target can have its own credential provider, but Gateway becomes a single MCP URL enabling access to all of the relevant tools for an agent across myriad APIs.

# %%
try:
    api_spec_file = "./prerequisite/lambda/api_spec.json"

    # Validate API spec file exists
    if not os.path.exists(api_spec_file):
        print(f"❌ API specification file not found: {api_spec_file}")
        sys.exit(1)

    api_spec = load_api_spec(api_spec_file)

    # Use Cognito for Inbound OAuth to our Gateway
    lambda_target_config = {
        "mcp": {
            "lambda": {
                "lambdaArn": get_ssm_parameter(
                    "/app/customersupport/agentcore/lambda_arn"
                ),
                "toolSchema": {"inlinePayload": api_spec},
            }
        }
    }

    # Create gateway target
    credential_config = [{"credentialProviderType": "GATEWAY_IAM_ROLE"}]

    create_target_response = gateway_client.create_gateway_target(
        gatewayIdentifier=gateway_id,
        name="LambdaUsingSDK",
        description="Lambda Target using SDK",
        targetConfiguration=lambda_target_config,
        credentialProviderConfigurations=credential_config,
    )

    print(f"✅ Gateway target created: {create_target_response['targetId']}")

except Exception as e:
    print(f"❌ Error creating gateway target: {str(e)}")
# Out:
# ❌ Error creating gateway target: An error occurred (ConflictException) when calling the CreateGatewayTarget operation: A target with name 'LambdaUsingSDK' already exists in this gateway

# %% [markdown]
# ## Step 7: Add our new MCP-based tools to our support agent
# Here we integrate our authentication token from Cognito into an MCPClient from Strands SDK to create an MCP Server object to integrate with our Strands Agent
# ### Step 7.1. Set up a secure MCP client object

# %%
print(f"Gateway Endpoint - MCP URL: {gateway['gateway_url']}")
# Set up MCP client
mcp_client = MCPClient(
    lambda: streamablehttp_client(
        gateway["gateway_url"],
        headers={"Authorization": f"Bearer {cognito_config['bearer_token']}"},
    )
)
# Out:
# Gateway Endpoint - MCP URL: https://customersupport-gw-mnyzzral2q.gateway.bedrock-agentcore.ap-southeast-1.amazonaws.com/mcp

# %% [markdown]
# ## Step 7.2. Access tools in our agent using our MCP client
# Now we will create our Strands Agent using the AgentCore Gateway we built along with the resources from previous labs. Our agent now uses a mix of local tools via our Strands Agent and MCP tools via AgentCore Gateway

# %%
SYSTEM_PROMPT
# Out:
# "You are a helpful and professional customer support assistant for an electronics e-commerce company.\nYour role is to:\n- Provide accurate information using the tools available to you\n- Support the customer with technical information and product specifications.\n- Be friendly, patient, and understanding with customers\n- Always offer additional help after answering questions\n- If you can't help with something, direct customers to the appropriate contact\n\nYou have access to the following tools:\n1. get_return_policy() - For warranty and return policy questions\n2. get_product_info() - To get information about a specific product\n3. web_search() - To access current technical documentation, or for updated information. \nAlways use the appropriate tool to get accurate, up-to-date information rather than making assumptions about electronic products or specifications."

# %%
from lab_helpers.lab1_strands_agent import (
    get_product_info,
    get_return_policy,
    get_technical_support,
    SYSTEM_PROMPT,
)

import uuid
from lab_helpers.lab2_memory import create_or_get_memory_resource
from bedrock_agentcore.memory.integrations.strands.config import AgentCoreMemoryConfig, RetrievalConfig
from bedrock_agentcore.memory.integrations.strands.session_manager import AgentCoreMemorySessionManager

memory_id = create_or_get_memory_resource()

SESSION_ID = str(uuid.uuid4())
CUSTOMER_ID = "customer_001"

memory_config = AgentCoreMemoryConfig(
        memory_id=memory_id,
        session_id=str(SESSION_ID),
        actor_id=CUSTOMER_ID,
        retrieval_config={
            "support/customer/{actorId}/semantic": RetrievalConfig(top_k=3, relevance_score=0.2),
            "support/customer/{actorId}/preferences": RetrievalConfig(top_k=3, relevance_score=0.2)
        }
    )

# Initialize the Bedrock model
model_id = "global.anthropic.claude-haiku-4-5-20251001-v1:0"
model = BedrockModel(
    model_id=model_id,
    temperature=0.3,  # Balanced between creativity and consistency
    region_name=REGION,
)


def create_agent(prompt):
    try:
        with mcp_client:
            tools = [
                get_product_info,
                get_return_policy,
                get_technical_support,
            ] + mcp_client.list_tools_sync()

            # Create the customer support agent
            agent = Agent(
                model=model,
                tools=tools,
                system_prompt=SYSTEM_PROMPT,
                session_manager=AgentCoreMemorySessionManager(memory_config, REGION),
            )
            response = agent(prompt)
            return response
    except Exception as e:
        raise e


print("✅ Customer support agent created successfully!")
# Out:
# ✅ Customer support agent created successfully!

# %%
with mcp_client:
    tools = [
        get_product_info,
        get_return_policy,
        get_technical_support,
    ] + mcp_client.list_tools_sync()

    # Create the customer support agent
    agent = Agent(
        model=model,
        tools=tools,
        system_prompt=SYSTEM_PROMPT,
        session_manager=AgentCoreMemorySessionManager(memory_config, REGION),
    )

print("*"*50)
print(f"Detected tools: {agent.tool_names}")
print("*"*50)
print(f"Detected tool configs: {agent.tool_registry.get_all_tools_config()}")
print("Notice that the tools names and tools_config include tools that we hosted on the gateway")
# Out:
# **************************************************
# Detected tools: ['get_product_info', 'get_return_policy', 'get_technical_support', 'LambdaUsingSDK___check_warranty_status', 'LambdaUsingSDK___web_search']
# **************************************************
# Detected tool configs: {'get_product_info': {'name': 'get_product_info', 'description': 'Get detailed technical specifications and information for electronics products.\n\nReturns:\n    Formatted product information including warranty, features, and policies', 'inputSchema': {'json': {'properties': {'product_type': {'description': "Electronics product type (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')", 'type': 'string'}}, 'required': ['product_type'], 'type': 'object'}}}, 'get_return_policy': {'name': 'get_return_policy', 'description': 'Get return policy information for a specific product category.\n\nReturns:\n    Formatted return policy details including timeframes and conditions', 'inputSchema': {'json': {'properties': {'product_category': {'description': "Electronics category (e.g., 'smartphones', 'laptops', 'accessories')", 'type': 'string'}}, 'required': ['product_category'], 'type': 'object'}}}, 'get_technical_support': {'name': 'get_technical_support', 'description': 'get_technical_support', 'inputSchema': {'json': {'properties': {'issue_description': {'description': 'Parameter issue_description', 'type': 'string'}}, 'required': ['issue_description'], 'type': 'object'}}}, 'LambdaUsingSDK___check_warranty_status': {'inputSchema': {'json': {'type': 'object', 'properties': {'customer_email': {'type': 'string', 'description': 'Property customer_email'}, 'serial_number': {'type': 'string', 'description': 'Property serial_number'}}, 'required': ['serial_number']}}, 'name': 'LambdaUsingSDK___check_warranty_status', 'description': 'Check the warranty status of a product using its serial number and optionally verify via email'}, 'LambdaUsingSDK___web_search': {'inputSchema': {'json': {'type': 'object', 'properties': {'keywords': {'description': 'The search query keywords', 'type': 'string'}, 'max_results': {'description': 'The maximum number of results to return', 'type': 'integer'}, 'region': {'description': 'The search region (e.g., us-en, uk-en, ru-ru)', 'type': 'string'}}, 'required': ['keywords']}}, 'name': 'LambdaUsingSDK___web_search', 'description': 'Search the web for updated information using DuckDuckGo'}}
# Notice that the tools names and tools_config include tools that we hosted on the gateway

# %% [markdown]
# ## Step 8: Test the agent with MCP tool access to existing APIs”
#
# Let's test our agent with sample queries to ensure all features work correctly. You should see 5 tools in the output.

# %%
test_prompts = [
    # Warranty Checks
    "List all of your tools",
    "I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?",
    "I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.",
    "What are the warranty support guidelines?",
    "How can I fix Lenovo Thinkpad with a blue screen",
    "Tell me detailed information about the technical documentation on installing a new CPU",
]


# Function to test the agent
def test_agent_responses(prompts):
    for i, prompt in enumerate(prompts, 1):
        print(f"\nTest Case {i}: {prompt}")
        print("-" * 50)
        try:
            response = create_agent(prompt)
            print(response)
        except Exception as e:
            print(f"Error: {str(e)}")
        print("-" * 50)


# Run the tests
test_agent_responses(test_prompts)

print("\\n✅ Basic testing completed!")
# Out:
# Test Case 1: List all of your tools
# --------------------------------------------------
#
#
# Here are all the tools I have available to assist you:
#
# ## **Available Tools:**
#
# ### **1. get_product_info()**
# - **Purpose:** Get detailed technical specifications and information for electronics products
# - **Returns:** Formatted product information including warranty, features, and policies
# - **Parameter:** `product_type` (e.g., 'laptops', 'smartphones', 'headphones', 'monitors', 'gaming consoles', etc.)
#
# ### **2. get_return_policy()**
# - **Purpose:** Get return policy information for a specific product category
# - **Returns:** Formatted return policy details including timeframes and conditions
# - **Parameter:** `product_category` (e.g., 'smartphones', 'laptops', 'accessories', 'gaming consoles', etc.)
#
# ### **3. get_technical_support()**
# - **Purpose:** Get technical support assistance for product issues
# - **Returns:** Troubleshooting guides and technical solutions
# - **Parameter:** `issue_description` (description of the technical problem)
#
# ### **4. LambdaUsingSDK___check_warranty_status()**
# - **Purpose:** Check the warranty status of a product using its serial number
# - **Returns:** Warranty status information, coverage details, and expiration dates
# - **Parameters:**
#   - `serial_number` (required) - Product serial number
#   - `customer_email` (optional) - For verification purposes
#
# ### **5. LambdaUsingSDK___web_search()**
# - **Purpose:** Search the web for updated information using DuckDuckGo
# - **Returns:** Current web search results for technical documentation and updated information
# - **Parameters:**
#   - `keywords` (required) - The search query keywords
#   - `max_results` (optional) - Maximum number of results to return
#   - `region` (optional) - Search region (e.g., us-en, uk-en, ru-ru)
#
# ---
#
# ## **How I Can Help You:**
#
# With these tools, I can assist you with:
#
# ✅ **Product Information** - Specs, features, and details for any electronics
# ✅ **Return & Warranty Policies** - Timeframes, conditions, and coverage details
# ✅ **Technical Support** - Troubleshooting guides for hardware and software issues
# ✅ **Warranty Status** - Check if your products are covered
# ✅ **Current Information** - Latest tech documentation and updates
#
# ---
#
# **What can I help you with today?**
#
# Based on your profile, I can help with:
# - 🎮 Gaming headphone recommendations for competitive FPS games
# - 💻 MacBook Pro overheating solutions for video editing
# - 📱 iPhone specifications and features
# - 🖥️ Technical documentation and hardware installation guides
# - 🔧 Troubleshooting and technical support
#
# Let me know how I can assist! 😊
#
# Here are all the tools I have available to assist you:
#
# ## **Available Tools:**
#
# ### **1. get_product_info()**
# - **Purpose:** Get detailed technical specifications and information for electronics products
# - **Returns:** Formatted product information including warranty, features, and policies
# - **Parameter:** `product_type` (e.g., 'laptops', 'smartphones', 'headphones', 'monitors', 'gaming consoles', etc.)
#
# ### **2. get_return_policy()**
# - **Purpose:** Get return policy information for a specific product category
# - **Returns:** Formatted return policy details including timeframes and conditions
# - **Parameter:** `product_category` (e.g., 'smartphones', 'laptops', 'accessories', 'gaming consoles', etc.)
#
# ### **3. get_technical_support()**
# - **Purpose:** Get technical support assistance for product issues
# - **Returns:** Troubleshooting guides and technical solutions
# - **Parameter:** `issue_description` (description of the technical problem)
#
# ### **4. LambdaUsingSDK___check_warranty_status()**
# - **Purpose:** Check the warranty status of a product using its serial number
# - **Returns:** Warranty status information, coverage details, and expiration dates
# - **Parameters:**
#   - `serial_number` (required) - Product serial number
#   - `customer_email` (optional) - For verification purposes
#
# ### **5. LambdaUsingSDK___web_search()**
# - **Purpose:** Search the web for updated information using DuckDuckGo
# - **Returns:** Current web search results for technical documentation and updated information
# - **Parameters:**
#   - `keywords` (required) - The search query keywords
#   - `max_results` (optional) - Maximum number of results to return
#   - `region` (optional) - Search region (e.g., us-en, uk-en, ru-ru)
#
# ---
#
# ## **How I Can Help You:**
#
# With these tools, I can assist you with:
#
# ✅ **Product Information** - Specs, features, and details for any electronics
# ✅ **Return & Warranty Policies** - Timeframes, conditions, and coverage details
# ✅ **Technical Support** - Troubleshooting guides for hardware and software issues
# ✅ **Warranty Status** - Check if your products are covered
# ✅ **Current Information** - Latest tech documentation and updates
#
# ---
#
# **What can I help you with today?**
#
# Based on your profile, I can help with:
# - 🎮 Gaming headphone recommendations for competitive FPS games
# - 💻 MacBook Pro overheating solutions for video editing
# - 📱 iPhone specifications and features
# - 🖥️ Technical documentation and hardware installation guides
# - 🔧 Troubleshooting and technical support
#
# Let me know how I can assist! 😊
#
# --------------------------------------------------
#
# Test Case 2: I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?
# --------------------------------------------------
#
#
# I'm sorry to hear you're experiencing overheating issues with your iPhone 14! Let me help you troubleshoot this. Let me get some technical support information for you.
# Tool #1: get_technical_support
# Successfully retrieved KB ID: XYYXNJDEHJ
# Great! Here are comprehensive troubleshooting steps to help resolve the overheating issue with your iPhone 14:
#
# ## **Quick Troubleshooting Steps:**
#
# ### **1. Battery & Performance Optimization**
# - ✅ **Enable Battery Optimization Settings** - Reduces power consumption
# - ✅ **Adjust Screen Brightness** - Lower brightness reduces heat generation
# - ✅ **Set Screen Timeout** - Auto-lock screen after shorter period
# - ✅ **Enable Low Power Mode** - Significantly reduces processing power and heat
# - ✅ **Manage Background App Refresh** - Disable for apps you don't need running constantly
#
# ### **2. Location & Connectivity Management**
# - ✅ **Configure Location Services** - Disable GPS for apps that don't need it
# - ✅ **Check Wi-Fi & Bluetooth** - Turn off when not in use
# - ✅ **Disable unnecessary connectivity** - Reduces power draw and heat
#
# ### **3. Storage & Performance**
# - ✅ **Check Available Storage Space** - Low storage can cause overheating
# - ✅ **Clear Cache and Temporary Files** - Frees up resources
# - ✅ **Close Unnecessary Applications** - Reduces CPU usage
# - ✅ **Manage Data Usage** - Heavy data transfers generate heat
#
# ### **4. Software Updates**
# - ✅ **Update to Latest iOS** - Apple often releases thermal management improvements
# - ✅ **Update All Apps** - Ensures compatibility and performance fixes
# - ✅ **Restart Your iPhone** - Clears temporary processes
#
# ### **5. Security Configuration**
# - ✅ **Enable Automatic Screen Lock** - Reduces unnecessary processing
# - ✅ **Configure Find My iPhone** - Ensure it's properly set up
# - ✅ **Enable Automatic App Updates** - Gets performance improvements
#
# ---
#
# ## **When to Seek Warranty Service:**
#
# Since you purchased your iPhone 14 **last month**, it should still be under the **1-year manufacturer warranty**. If overheating persists after trying these steps, you may have a **hardware issue** that qualifies for warranty coverage.
#
# ### **Warranty Coverage Includes:**
# ✅ Manufacturing defects - Full coverage
# ✅ Thermal management issues - Covered
# ✅ Software issues - Covered if not user-caused
# ❌ Normal wear and tear - Not covered
# ❌ Accidental damage - Extended warranty available
#
# ---
#
# ## **Next Steps:**
#
# **I can help you with:**
#
# 1. **Check Your Warranty Status** - I'll need your iPhone 14 serial number
# 2. **Get Return Policy Information** - For potential replacement or repair
# 3. **Connect with Technical Support** - For advanced diagnostics
#
# **Would you like me to:**
# - ✅ Check your iPhone 14's warranty status? (I'll need the serial number)
# - ✅ Get information about our return/replacement policy?
# - ✅ Provide more specific troubleshooting for your use case?
#
# Since you do video editing work on your MacBook Pro, I understand how important device stability and thermal management are to you. Let me know how I can help resolve this iPhone 14 overheating issue! 📱Great! Here are comprehensive troubleshooting steps to help resolve the overheating issue with your iPhone 14:
#
# ## **Quick Troubleshooting Steps:**
#
# ### **1. Battery & Performance Optimization**
# - ✅ **Enable Battery Optimization Settings** - Reduces power consumption
# - ✅ **Adjust Screen Brightness** - Lower brightness reduces heat generation
# - ✅ **Set Screen Timeout** - Auto-lock screen after shorter period
# - ✅ **Enable Low Power Mode** - Significantly reduces processing power and heat
# - ✅ **Manage Background App Refresh** - Disable for apps you don't need running constantly
#
# ### **2. Location & Connectivity Management**
# - ✅ **Configure Location Services** - Disable GPS for apps that don't need it
# - ✅ **Check Wi-Fi & Bluetooth** - Turn off when not in use
# - ✅ **Disable unnecessary connectivity** - Reduces power draw and heat
#
# ### **3. Storage & Performance**
# - ✅ **Check Available Storage Space** - Low storage can cause overheating
# - ✅ **Clear Cache and Temporary Files** - Frees up resources
# - ✅ **Close Unnecessary Applications** - Reduces CPU usage
# - ✅ **Manage Data Usage** - Heavy data transfers generate heat
#
# ### **4. Software Updates**
# - ✅ **Update to Latest iOS** - Apple often releases thermal management improvements
# - ✅ **Update All Apps** - Ensures compatibility and performance fixes
# - ✅ **Restart Your iPhone** - Clears temporary processes
#
# ### **5. Security Configuration**
# - ✅ **Enable Automatic Screen Lock** - Reduces unnecessary processing
# - ✅ **Configure Find My iPhone** - Ensure it's properly set up
# - ✅ **Enable Automatic App Updates** - Gets performance improvements
#
# ---
#
# ## **When to Seek Warranty Service:**
#
# Since you purchased your iPhone 14 **last month**, it should still be under the **1-year manufacturer warranty**. If overheating persists after trying these steps, you may have a **hardware issue** that qualifies for warranty coverage.
#
# ### **Warranty Coverage Includes:**
# ✅ Manufacturing defects - Full coverage
# ✅ Thermal management issues - Covered
# ✅ Software issues - Covered if not user-caused
# ❌ Normal wear and tear - Not covered
# ❌ Accidental damage - Extended warranty available
#
# ---
#
# ## **Next Steps:**
#
# **I can help you with:**
#
# 1. **Check Your Warranty Status** - I'll need your iPhone 14 serial number
# 2. **Get Return Policy Information** - For potential replacement or repair
# 3. **Connect with Technical Support** - For advanced diagnostics
#
# **Would you like me to:**
# - ✅ Check your iPhone 14's warranty status? (I'll need the serial number)
# - ✅ Get information about our return/replacement policy?
# - ✅ Provide more specific troubleshooting for your use case?
#
# Since you do video editing work on your MacBook Pro, I understand how important device stability and thermal management are to you. Let me know how I can help resolve this iPhone 14 overheating issue! 📱
#
# --------------------------------------------------
#
# Test Case 3: I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.
# --------------------------------------------------
#
#
# Let me check the warranty status for your Gaming Console Pro device with that serial number.
# Tool #1: LambdaUsingSDK___check_warranty_status
# I've checked your warranty status for the Gaming Console Pro. Here's what I found:
#
# ## **Warranty Status Summary:**
#
# | Detail | Information |
# |--------|-------------|
# | **Product** | Gaming Console Pro |
# | **Serial Number** | MNO33333333 |
# | **Purchase Date** | November 25, 2023 |
# | **Warranty End Date** | November 25, 2024 |
# | **Warranty Type** | Gaming Warranty |
# | **Status** | ❌ **EXPIRED** (386 days ago) |
#
# ## **What Was Covered:**
# Your Gaming Warranty included coverage for:
# - ✅ Controller issues
# - ✅ Overheating protection
# - ✅ Hard drive replacement
#
# ---
#
# ## **Your Options Now:**
#
# Since your warranty has expired, here are your available options:
#
# ### **1. Extended Warranty Plans**
# - We may have extended warranty options available
# - Provides continued coverage for future issues
# - Includes accidental damage protection options
# - Extended coverage periods available
#
# ### **2. Out-of-Warranty Repair Service**
# - We can provide a quote for repair services
# - Quote will be provided before any work begins
# - Express service available for additional fee
# - On-site service available for business customers
#
# ### **3. Replacement Device Program**
# - Explore replacement options if repair isn't cost-effective
# - Trade-in programs may be available
#
# ---
#
# ## **Support Channels Available:**
#
# - 💬 **Online Chat** - 24/7 availability
# - 📞 **Phone Support** - Business hours
# - 📧 **Email Support** - 24-hour response time
# - 🎥 **Video Troubleshooting** - Appointment based
#
# ---
#
# ## **What Can I Help You With?**
#
# **Would you like me to:**
# - ✅ Get information about our extended warranty options?
# - ✅ Provide details on out-of-warranty repair pricing?
# - ✅ Get the return policy for gaming consoles?
# - ✅ Connect you with technical support for diagnostics?
# - ✅ Help with troubleshooting your console issue?
#
# **What issue are you experiencing with your Gaming Console Pro?** This will help me provide the best support options for you!I've checked your warranty status for the Gaming Console Pro. Here's what I found:
#
# ## **Warranty Status Summary:**
#
# | Detail | Information |
# |--------|-------------|
# | **Product** | Gaming Console Pro |
# | **Serial Number** | MNO33333333 |
# | **Purchase Date** | November 25, 2023 |
# | **Warranty End Date** | November 25, 2024 |
# | **Warranty Type** | Gaming Warranty |
# | **Status** | ❌ **EXPIRED** (386 days ago) |
#
# ## **What Was Covered:**
# Your Gaming Warranty included coverage for:
# - ✅ Controller issues
# - ✅ Overheating protection
# - ✅ Hard drive replacement
#
# ---
#
# ## **Your Options Now:**
#
# Since your warranty has expired, here are your available options:
#
# ### **1. Extended Warranty Plans**
# - We may have extended warranty options available
# - Provides continued coverage for future issues
# - Includes accidental damage protection options
# - Extended coverage periods available
#
# ### **2. Out-of-Warranty Repair Service**
# - We can provide a quote for repair services
# - Quote will be provided before any work begins
# - Express service available for additional fee
# - On-site service available for business customers
#
# ### **3. Replacement Device Program**
# - Explore replacement options if repair isn't cost-effective
# - Trade-in programs may be available
#
# ---
#
# ## **Support Channels Available:**
#
# - 💬 **Online Chat** - 24/7 availability
# - 📞 **Phone Support** - Business hours
# - 📧 **Email Support** - 24-hour response time
# - 🎥 **Video Troubleshooting** - Appointment based
#
# ---
#
# ## **What Can I Help You With?**
#
# **Would you like me to:**
# - ✅ Get information about our extended warranty options?
# - ✅ Provide details on out-of-warranty repair pricing?
# - ✅ Get the return policy for gaming consoles?
# - ✅ Connect you with technical support for diagnostics?
# - ✅ Help with troubleshooting your console issue?
#
# **What issue are you experiencing with your Gaming Console Pro?** This will help me provide the best support options for you!
#
# --------------------------------------------------
#
# Test Case 4: What are the warranty support guidelines?
# --------------------------------------------------
#
#
# Let me get comprehensive warranty support guidelines for you.
# Tool #1: get_return_policy
#
# Tool #2: LambdaUsingSDK___web_search
# Great question! Here's comprehensive information about our warranty support guidelines:
#
# ## **Warranty Support Guidelines:**
#
# ### **Coverage Details:**
#
# | Coverage Type | Status |
# |---------------|--------|
# | **Manufacturing Defects** | ✅ Full coverage |
# | **Defects in Materials & Workmanship** | ✅ Covered |
# | **Mechanical & Electrical Failures** | ✅ Covered (normal use) |
# | **Power Surges** | ✅ Covered |
# | **Normal Wear and Tear** | ❌ NOT covered |
# | **Accidental Damage** | ❌ NOT covered (extended warranty available) |
# | **Water Damage** | ❌ Generally NOT covered (check IP rating) |
# | **Software Issues** | ✅ Covered if not user-caused |
# | **Neglect or Poor Maintenance** | ❌ NOT covered |
#
# ---
#
# ## **Warranty Claims Process:**
#
# ### **Step-by-Step:**
# 1. **Gather Documentation**
#    - Proof of purchase
#    - Serial number
#    - Order confirmation
#
# 2. **Contact Technical Support**
#    - Describe the issue
#    - Provide device details
#    - Request diagnosis
#
# 3. **Complete Warranty Claim Form**
#    - Fill out claim documentation
#    - Provide supporting evidence
#    - Submit for review
#
# 4. **Package Device Securely**
#    - Use original packaging if available
#    - Include all accessories
#    - Ship to designated address
#
# 5. **Track Repair Status**
#    - Monitor through online portal
#    - Receive updates on progress
#    - Get notification when ready
#
# ---
#
# ## **Service Options Available:**
#
# ### **In-Warranty Repairs**
# - ✅ Free parts and labor
# - ✅ No out-of-pocket costs
# - ✅ Standard turnaround time
#
# ### **Out-of-Warranty Repairs**
# - 📋 Quote provided before service
# - 💰 Transparent pricing
# - ⚡ Express service available (additional fee)
# - 🏢 On-site service for business customers
#
# ### **Extended Warranty Plans**
# - 🛡️ Accidental damage protection
# - 📅 Extended coverage periods
# - 📞 Premium technical support
# - 🔄 Replacement device programs
#
# ---
#
# ## **Support Channels:**
#
# | Channel | Availability | Response Time |
# |---------|--------------|----------------|
# | **Online Chat** | 24/7 | Immediate |
# | **Phone Support** | Business hours | Real-time |
# | **Email Support** | 24/7 | 24-hour response |
# | **Video Troubleshooting** | Appointment based | Scheduled |
#
# ---
#
# ## **Return Policy (Gaming Consoles):**
#
# - **Return Window:** 30 days from delivery
# - **Condition Required:** Original condition with all included components
# - **Process:** Contact technical support
# - **Refund Timeline:** 5-7 business days after inspection
# - **Shipping:** Return shipping policies vary
# - **Warranty:** Standard manufacturer warranty applies
#
# ---
#
# ## **Important Notes:**
#
# ### **For Your Gaming Console Pro:**
# Since your warranty expired on November 25, 2024, you would need:
# - ✅ Extended warranty for continued coverage
# - ✅ Out-of-warranty repair quote for any issues
# - ✅ Potential replacement device program
#
# ### **Warranty Registration:**
# - Register your product for warranty purposes
# - Helps with claims processing
# - Enables faster support
#
# ---
#
# ## **How Can I Help You Further?**
#
# **Would you like me to:**
# - ✅ Explain coverage for a specific issue with your Gaming Console Pro?
# - ✅ Get information about extended warranty options?
# - ✅ Provide out-of-warranty repair pricing?
# - ✅ Help with the warranty claim process?
# - ✅ Connect you with technical support?
#
# **What specific warranty question do you have about your Gaming Console Pro or any other device?** I'm here to help! 🛡️Great question! Here's comprehensive information about our warranty support guidelines:
#
# ## **Warranty Support Guidelines:**
#
# ### **Coverage Details:**
#
# | Coverage Type | Status |
# |---------------|--------|
# | **Manufacturing Defects** | ✅ Full coverage |
# | **Defects in Materials & Workmanship** | ✅ Covered |
# | **Mechanical & Electrical Failures** | ✅ Covered (normal use) |
# | **Power Surges** | ✅ Covered |
# | **Normal Wear and Tear** | ❌ NOT covered |
# | **Accidental Damage** | ❌ NOT covered (extended warranty available) |
# | **Water Damage** | ❌ Generally NOT covered (check IP rating) |
# | **Software Issues** | ✅ Covered if not user-caused |
# | **Neglect or Poor Maintenance** | ❌ NOT covered |
#
# ---
#
# ## **Warranty Claims Process:**
#
# ### **Step-by-Step:**
# 1. **Gather Documentation**
#    - Proof of purchase
#    - Serial number
#    - Order confirmation
#
# 2. **Contact Technical Support**
#    - Describe the issue
#    - Provide device details
#    - Request diagnosis
#
# 3. **Complete Warranty Claim Form**
#    - Fill out claim documentation
#    - Provide supporting evidence
#    - Submit for review
#
# 4. **Package Device Securely**
#    - Use original packaging if available
#    - Include all accessories
#    - Ship to designated address
#
# 5. **Track Repair Status**
#    - Monitor through online portal
#    - Receive updates on progress
#    - Get notification when ready
#
# ---
#
# ## **Service Options Available:**
#
# ### **In-Warranty Repairs**
# - ✅ Free parts and labor
# - ✅ No out-of-pocket costs
# - ✅ Standard turnaround time
#
# ### **Out-of-Warranty Repairs**
# - 📋 Quote provided before service
# - 💰 Transparent pricing
# - ⚡ Express service available (additional fee)
# - 🏢 On-site service for business customers
#
# ### **Extended Warranty Plans**
# - 🛡️ Accidental damage protection
# - 📅 Extended coverage periods
# - 📞 Premium technical support
# - 🔄 Replacement device programs
#
# ---
#
# ## **Support Channels:**
#
# | Channel | Availability | Response Time |
# |---------|--------------|----------------|
# | **Online Chat** | 24/7 | Immediate |
# | **Phone Support** | Business hours | Real-time |
# | **Email Support** | 24/7 | 24-hour response |
# | **Video Troubleshooting** | Appointment based | Scheduled |
#
# ---
#
# ## **Return Policy (Gaming Consoles):**
#
# - **Return Window:** 30 days from delivery
# - **Condition Required:** Original condition with all included components
# - **Process:** Contact technical support
# - **Refund Timeline:** 5-7 business days after inspection
# - **Shipping:** Return shipping policies vary
# - **Warranty:** Standard manufacturer warranty applies
#
# ---
#
# ## **Important Notes:**
#
# ### **For Your Gaming Console Pro:**
# Since your warranty expired on November 25, 2024, you would need:
# - ✅ Extended warranty for continued coverage
# - ✅ Out-of-warranty repair quote for any issues
# - ✅ Potential replacement device program
#
# ### **Warranty Registration:**
# - Register your product for warranty purposes
# - Helps with claims processing
# - Enables faster support
#
# ---
#
# ## **How Can I Help You Further?**
#
# **Would you like me to:**
# - ✅ Explain coverage for a specific issue with your Gaming Console Pro?
# - ✅ Get information about extended warranty options?
# - ✅ Provide out-of-warranty repair pricing?
# - ✅ Help with the warranty claim process?
# - ✅ Connect you with technical support?
#
# **What specific warranty question do you have about your Gaming Console Pro or any other device?** I'm here to help! 🛡️
#
# --------------------------------------------------
#
# Test Case 5: How can I fix Lenovo Thinkpad with a blue screen
# --------------------------------------------------
#
#
# Let me get technical support information for your Lenovo ThinkPad blue screen issue.
# Tool #1: get_technical_support
#
# Tool #2: LambdaUsingSDK___web_search
# Successfully retrieved KB ID: XYYXNJDEHJ
# I'm sorry to hear you're experiencing a blue screen issue with your Lenovo ThinkPad! This is a serious issue that needs attention. Here are comprehensive troubleshooting steps:
#
# ## **Blue Screen Troubleshooting Steps:**
#
# ### **Immediate Actions:**
#
# #### **1. Note the Error Code**
# - Write down any error message or code displayed on the blue screen
# - This helps identify the specific problem
# - Look for "STOP" codes or error messages
#
# #### **2. Force Restart Your ThinkPad**
# - Hold the power button for 10 seconds
# - Let it boot normally
# - See if the issue persists
#
# #### **3. Boot in Safe Mode**
# - Restart your ThinkPad
# - Press **F8 repeatedly** during boot
# - Select "Safe Mode with Networking"
# - This helps identify if third-party software is causing the issue
#
# ---
#
# ## **Software-Related Fixes:**
#
# #### **4. Remove External Hardware**
# - Disconnect all external devices:
#   - Secondary monitors
#   - External keyboards
#   - Printers, scanners
#   - External storage devices
#   - USB devices
# - Try booting without them
# - Reconnect one at a time to identify conflicts
#
# #### **5. Update All Drivers**
# - Download **Lenovo Vantage** or **Lenovo Update** tool
# - Update all drivers, especially:
#   - Chipset drivers
#   - Graphics drivers
#   - Network drivers
#   - Storage drivers
# - Restart after each update
#
# #### **6. Check for Windows Updates**
# - Go to Settings > Update & Security
# - Check for pending Windows updates
# - Install all available updates
# - Restart the system
#
# #### **7. Remove Conflicting Updates**
# - If BSOD started after a Windows update:
#   - Go to Settings > Update & Security > Update history
#   - Click "Uninstall updates"
#   - Remove the problematic update
#   - Reinstall it fresh
#
# ---
#
# ## **BIOS-Related Fixes:**
#
# #### **8. Reset BIOS Settings**
# - Restart your ThinkPad
# - Press **F2 key** as soon as the Lenovo logo appears
# - Set SATA mode to **AHCI**
# - Press **F10** to save settings
# - System will auto-reboot and reset BIOS
#
# #### **9. Check BIOS for Corruption**
# - Enter BIOS (F2 during startup)
# - Look for any error messages
# - Verify all settings are correct
# - Reset to defaults if needed
#
# ---
#
# ## **System Repair Tools:**
#
# #### **10. Run Startup Repair**
# - Reboot while pressing the boot key constantly (usually **F12** or **Fn+F12**)
# - Enter boot menu
# - Set bootable USB on priority (if you have Windows recovery media)
# - Save and exit
# - Click **Automated Repair**
# - Wait for repair to complete
# - Click **Restart**
#
# #### **11. System Restore**
# - Boot into Safe Mode
# - Go to Settings > System > About > System protection
# - Click "System Restore"
# - Choose a restore point before the BSOD started
# - Follow the wizard to restore
#
# #### **12. PC Reset/Restore**
# - Go to Settings > System > Recovery
# - Click "Reset this PC"
# - Choose "Keep my files" or "Remove everything"
# - Follow the wizard
# - System will restart automatically
#
# ---
#
# ## **Hardware-Related Checks:**
#
# #### **13. Check Hard Drive Health**
# - Run disk cleanup and defragmentation
# - Check hard drive for errors
# - Keep 15-20% disk space free
# - Use ThinkPad Diagnostics tool
#
# #### **14. Monitor Temperature Levels**
# - Excessive heat can cause blue screens
# - Ensure proper ventilation
# - Clean vents and fans with compressed air
# - Monitor temperatures during operation
#
# #### **15. Check RAM**
# - Run memory diagnostics (built into Windows)
# - Reseat RAM if possible
# - Test with one RAM stick at a time
#
# #### **16. Check Power Supply**
# - Verify power cable connections
# - Try a different power outlet
# - Check for physical damage to adapter
#
# ---
#
# ## **Maintenance Tips:**
#
# ### **Daily Care:**
# - Keep laptop on hard flat surfaces for proper ventilation
# - Avoid eating or drinking near the laptop
# - Close laptop carefully without slamming
#
# ### **Weekly Maintenance:**
# - Clean keyboard with compressed air
# - Wipe down exterior with damp cloth
# - Check for software updates
# - Empty downloads and temp folders
#
# ### **Monthly Tasks:**
# - Deep clean vents and fans
# - Check battery health and calibrate
# - Update all drivers and software
# - Run disk cleanup and defragmentation
# - Backup important data
#
# ---
#
# ## **When to Seek Professional Help:**
#
# If the blue screen persists after these steps, it could indicate:
# - **Hardware failure** (hard drive, RAM, motherboard)
# - **Serious software corruption**
# - **Driver conflicts**
# - **BIOS corruption**
#
# ---
#
# ## **I Can Help You With:**
#
# **Do you have your ThinkPad's serial number?** I can:
# - ✅ Check if it's still under warranty
# - ✅ Get information about repair options
# - ✅ Connect you with technical support for advanced diagnostics
# - ✅ Provide information about our return/replacement policy
#
# **What specific error code or message are you seeing on the blue screen?** This will help me provide more targeted troubleshooting!
#
# Would you like me to help with any of these steps, or do you need additional technical support? 🛠️I'm sorry to hear you're experiencing a blue screen issue with your Lenovo ThinkPad! This is a serious issue that needs attention. Here are comprehensive troubleshooting steps:
#
# ## **Blue Screen Troubleshooting Steps:**
#
# ### **Immediate Actions:**
#
# #### **1. Note the Error Code**
# - Write down any error message or code displayed on the blue screen
# - This helps identify the specific problem
# - Look for "STOP" codes or error messages
#
# #### **2. Force Restart Your ThinkPad**
# - Hold the power button for 10 seconds
# - Let it boot normally
# - See if the issue persists
#
# #### **3. Boot in Safe Mode**
# - Restart your ThinkPad
# - Press **F8 repeatedly** during boot
# - Select "Safe Mode with Networking"
# - This helps identify if third-party software is causing the issue
#
# ---
#
# ## **Software-Related Fixes:**
#
# #### **4. Remove External Hardware**
# - Disconnect all external devices:
#   - Secondary monitors
#   - External keyboards
#   - Printers, scanners
#   - External storage devices
#   - USB devices
# - Try booting without them
# - Reconnect one at a time to identify conflicts
#
# #### **5. Update All Drivers**
# - Download **Lenovo Vantage** or **Lenovo Update** tool
# - Update all drivers, especially:
#   - Chipset drivers
#   - Graphics drivers
#   - Network drivers
#   - Storage drivers
# - Restart after each update
#
# #### **6. Check for Windows Updates**
# - Go to Settings > Update & Security
# - Check for pending Windows updates
# - Install all available updates
# - Restart the system
#
# #### **7. Remove Conflicting Updates**
# - If BSOD started after a Windows update:
#   - Go to Settings > Update & Security > Update history
#   - Click "Uninstall updates"
#   - Remove the problematic update
#   - Reinstall it fresh
#
# ---
#
# ## **BIOS-Related Fixes:**
#
# #### **8. Reset BIOS Settings**
# - Restart your ThinkPad
# - Press **F2 key** as soon as the Lenovo logo appears
# - Set SATA mode to **AHCI**
# - Press **F10** to save settings
# - System will auto-reboot and reset BIOS
#
# #### **9. Check BIOS for Corruption**
# - Enter BIOS (F2 during startup)
# - Look for any error messages
# - Verify all settings are correct
# - Reset to defaults if needed
#
# ---
#
# ## **System Repair Tools:**
#
# #### **10. Run Startup Repair**
# - Reboot while pressing the boot key constantly (usually **F12** or **Fn+F12**)
# - Enter boot menu
# - Set bootable USB on priority (if you have Windows recovery media)
# - Save and exit
# - Click **Automated Repair**
# - Wait for repair to complete
# - Click **Restart**
#
# #### **11. System Restore**
# - Boot into Safe Mode
# - Go to Settings > System > About > System protection
# - Click "System Restore"
# - Choose a restore point before the BSOD started
# - Follow the wizard to restore
#
# #### **12. PC Reset/Restore**
# - Go to Settings > System > Recovery
# - Click "Reset this PC"
# - Choose "Keep my files" or "Remove everything"
# - Follow the wizard
# - System will restart automatically
#
# ---
#
# ## **Hardware-Related Checks:**
#
# #### **13. Check Hard Drive Health**
# - Run disk cleanup and defragmentation
# - Check hard drive for errors
# - Keep 15-20% disk space free
# - Use ThinkPad Diagnostics tool
#
# #### **14. Monitor Temperature Levels**
# - Excessive heat can cause blue screens
# - Ensure proper ventilation
# - Clean vents and fans with compressed air
# - Monitor temperatures during operation
#
# #### **15. Check RAM**
# - Run memory diagnostics (built into Windows)
# - Reseat RAM if possible
# - Test with one RAM stick at a time
#
# #### **16. Check Power Supply**
# - Verify power cable connections
# - Try a different power outlet
# - Check for physical damage to adapter
#
# ---
#
# ## **Maintenance Tips:**
#
# ### **Daily Care:**
# - Keep laptop on hard flat surfaces for proper ventilation
# - Avoid eating or drinking near the laptop
# - Close laptop carefully without slamming
#
# ### **Weekly Maintenance:**
# - Clean keyboard with compressed air
# - Wipe down exterior with damp cloth
# - Check for software updates
# - Empty downloads and temp folders
#
# ### **Monthly Tasks:**
# - Deep clean vents and fans
# - Check battery health and calibrate
# - Update all drivers and software
# - Run disk cleanup and defragmentation
# - Backup important data
#
# ---
#
# ## **When to Seek Professional Help:**
#
# If the blue screen persists after these steps, it could indicate:
# - **Hardware failure** (hard drive, RAM, motherboard)
# - **Serious software corruption**
# - **Driver conflicts**
# - **BIOS corruption**
#
# ---
#
# ## **I Can Help You With:**
#
# **Do you have your ThinkPad's serial number?** I can:
# - ✅ Check if it's still under warranty
# - ✅ Get information about repair options
# - ✅ Connect you with technical support for advanced diagnostics
# - ✅ Provide information about our return/replacement policy
#
# **What specific error code or message are you seeing on the blue screen?** This will help me provide more targeted troubleshooting!
#
# Would you like me to help with any of these steps, or do you need additional technical support? 🛠️
#
# --------------------------------------------------
#
# Test Case 6: Tell me detailed information about the technical documentation on installing a new CPU
# --------------------------------------------------
#
#
# Let me search for detailed technical documentation on CPU installation for you.
# Tool #1: LambdaUsingSDK___web_search
#
# Tool #2: LambdaUsingSDK___web_search
# Let me search for more specific CPU installation documentation.
# Tool #3: LambdaUsingSDK___web_search
# Perfect! Let me provide you with comprehensive technical documentation on CPU installation:
#
# ## **CPU Installation - Detailed Technical Guide**
#
# ### **Pre-Installation Requirements:**
#
# #### **1. Compatibility Check**
# - **Socket Type** - Verify your motherboard socket matches the CPU socket:
#   - **Intel:** LGA1700, LGA1851, LGA1200, etc.
#   - **AMD:** AM5, AM4, etc.
# - **Power Requirements** - Ensure your PSU has sufficient wattage for the new CPU
# - **BIOS Compatibility** - Check if your motherboard BIOS supports the new CPU
# - **Thermal Solution** - Verify your cooler is compatible with your socket type
#
# #### **2. Tools & Materials Needed**
# - Anti-static wrist strap
# - Thermal paste (Arctic MX-6, Noctua NT-H2, or equivalent)
# - CPU cooler (compatible with your socket)
# - Screwdriver (usually Phillips head PH2)
# - Isopropyl alcohol (for cleaning)
# - Lint-free cloth or coffee filters
# - Thermal paste spreader (plastic card or included tool)
#
# ---
#
# ## **Step-by-Step Installation Process:**
#
# ### **Step 1: Power Down & Safety**
# - Shut down your computer completely
# - Unplug the power cable from the PSU
# - Wait 5 minutes for residual power to dissipate
# - Put on anti-static wrist strap connected to case
# - Ground yourself by touching a metal part of the case
#
# ### **Step 2: Remove Old CPU (if applicable)**
# - Remove the CPU cooler (follow cooler-specific instructions)
# - Locate the CPU socket retention mechanism
# - Carefully lift the retention arm/lever
# - Gently remove the old CPU
# - Clean the socket with compressed air
# - Wipe socket clean with lint-free cloth
#
# ### **Step 3: Prepare the Socket**
# - Inspect the socket for bent pins or damage
# - Clean any dust or debris with compressed air
# - Ensure the socket is completely dry
# - Verify socket is in correct position for new CPU
#
# ### **Step 4: Install New CPU**
#
# #### **Alignment & Orientation:**
# - **Look for alignment markers:**
#   - Usually triangles or notches on CPU and socket
#   - Match CPU markers with socket markers
#   - Ensure proper orientation before insertion
#
# #### **Gentle Placement:**
# - Carefully place CPU into socket without forcing
# - CPU should slide in smoothly with minimal pressure
# - **Never force the CPU** - if it doesn't fit easily, check alignment
# - Lower retention arm/lever gently until it clicks
#
# #### **Socket-Specific Instructions:**
#
# **For Intel (LGA1700/LGA1851):**
# - Lift retention frame
# - Place CPU with notches aligned
# - Lower retention frame and secure
#
# **For AMD (AM5/AM4):**
# - Lift retention lever
# - Place CPU with notches aligned
# - Lower retention lever until it locks
# - Ensure CPU sits flush in socket
#
# ### **Step 5: Apply Thermal Paste**
#
# #### **Amount & Application:**
# - **Pea-sized amount:** Small dot in center of CPU IHS (Integrated Heat Spreader)
# - **Alternative method:** Small line across center
# - **Avoid excess:** Too much paste reduces cooling efficiency
# - **Coverage:** Let cooler spread it or use plastic spreader for even coverage
#
# #### **Thermal Paste Types:**
# - Arctic MX-6 (recommended)
# - Noctua NT-H2
# - Thermal Grizzly Kryonaut
# - Stock paste on cooler (if pre-applied)
#
# #### **Application Technique:**
# - Place small amount on CPU center
# - Use plastic spreader to spread evenly
# - Ensure entire IHS is covered
# - Avoid getting paste on socket or surrounding areas
#
# ### **Step 6: Install CPU Cooler**
#
# #### **Mounting Instructions:**
# - Follow your specific cooler's installation manual
# - **For Socket-Specific Coolers:**
#   - **Intel:** Use Intel mounting brackets (LGA1700/LGA1851)
#   - **AMD:** Use AMD mounting brackets (AM5/AM4)
# - Ensure proper mounting pressure (not too tight, not too loose)
# - Verify cooler makes full contact with CPU
# - Secure all mounting brackets and fasteners
#
# #### **Cooler Types:**
# - **Air Coolers:** Screw-down mounting
# - **Liquid Coolers (AIO):** Bracket mounting with pump head
# - **Stock Coolers:** Clip-on mounting
#
# ### **Step 7: Reconnect Power & Boot**
# - Reconnect all power cables:
#   - 24-pin ATX power
#   - 8-pin CPU power (4+4 pin)
# - Power on the system
# - Enter BIOS during startup (usually Delete, F2, or F12)
# - Verify CPU is recognized with correct specifications
#
# ---
#
# ## **BIOS Configuration After Installation:**
#
# ### **Important BIOS Steps:**
#
# #### **1. CPU Recognition**
# - Confirm new CPU is detected
# - Verify CPU name and speed
# - Check core count matches specifications
#
# #### **2. Voltage Settings**
# - Set CPU voltage to **AUTO** (recommended)
# - Do not manually adjust unless overclocking
# - Verify voltage is within safe range
#
# #### **3. XMP/DOCP Settings**
# - Re-enable if you have overclocking profiles
# - **Intel:** Intel XMP (Extreme Memory Profile)
# - **AMD:** AMD DOCP (Direct Overclocking Profile)
#
# #### **4. Temperature Monitoring**
# - Check CPU temperatures are normal
# - Monitor during boot and operation
# - Verify cooler is functioning properly
#
# #### **5. fTPM Reset (if needed)**
# - If you see "fTPM/PSP NV Corrupted" error:
#   - Enter BIOS setup
#   - Find fTPM option
#   - Select "Reset fTPM"
#   - Save and exit
#
# #### **6. Update BIOS (if needed)**
# - Check for BIOS updates for new CPU support
# - Download latest BIOS from motherboard manufacturer
# - Follow manufacturer's update procedure
# - Ensure stable power during update
#
# ---
#
# ## **Temperature Guidelines:**
#
# | Temperature Range | Status | Action |
# |------------------|--------|--------|
# | 30-50°C (Idle) | Normal | ✅ OK |
# | 50-70°C (Load) | Normal | ✅ OK |
# | 70-85°C (Heavy Load) | Acceptable | ✅ OK |
# | 85-95°C | Concerning | ⚠️ Monitor |
# | 95°C+ | Critical | ❌ Shut down |
# | 100°C+ | Dangerous | ❌ Immediate shutdown |
#
# ---
#
# ## **Post-Installation Verification:**
#
# ### **1. Run System Tests**
# - Boot into Windows/Linux normally
# - Check Device Manager for CPU recognition
# - Run CPU-Z or similar tool to verify specs
# - Verify CPU name, cores, threads, and speed
#
# ### **2. Monitor Temperatures**
# - Use HWInfo64 or similar monitoring software
# - Run stress tests:
#   - Prime95 (CPU intensive)
#   - MemTest86 (memory test)
#   - Cinebench (performance benchmark)
# - Verify temperatures stay within safe ranges
#
# ### **3. Check Performance**
# - Run benchmarks to verify performance
# - Monitor for thermal throttling
# - Ensure system stability during extended use
# - Check for any error messages
#
# ### **4. Verify Stability**
# - Run system for 30+ minutes under load
# - Monitor temperatures and clock speeds
# - Check for crashes or freezes
# - Verify all cores are recognized
#
# ---
#
# ## **Common Issues & Solutions:**
#
# | Issue | Cause | Solution |
# |-------|-------|----------|
# | CPU not recognized | Improper seating, BIOS outdated | Reseat CPU, update BIOS |
# | High temperatures | Poor thermal paste contact | Reapply thermal paste, check cooler contact |
# | System won't boot | Socket misalignment, power issues | Verify socket alignment, check power connections |
# | Thermal throttling | Inadequate cooling | Improve case airflow, reapply paste, upgrade cooler |
# | fTPM error | TPM firmware issue | Reset fTPM in BIOS |
# | BSOD errors | Driver incompatibility | Update chipset drivers, update BIOS |
# | Slow performance | Thermal throttling, BIOS settings | Check temps, verify clock speeds in BIOS |
#
# ---
#
# ## **Safety Warnings:**
#
# ⚠️ **Critical Precautions:**
# - ✅ Always use anti-static protection
# - ✅ Never force the CPU into the socket
# - ✅ Don't touch the CPU pins or socket pins
# - ✅ Ensure system is completely powered down before installation
# - ✅ Allow adequate cooling time before stress testing
# - ✅ Never apply excessive thermal paste
# - ✅ Verify socket type before purchasing CPU
# - ✅ Check motherboard compatibility before installation
#
# ---
#
# ## **Socket-Specific Information:**
#
# ### **Intel Sockets:**
# - **LGA1700** - 12th/13th/14th Gen Core processors
# - **LGA1851** - Arrow Lake processors
# - **LGA1200** - 10th/11th Gen Core processors
#
# ### **AMD Sockets:**
# - **AM5** - Ryzen 7000/8000/9000 series
# - **AM4** - Ryzen 3000/5000 series
#
# ---
#
# ## **Recommended Resources:**
#
# - **Motherboard Manual** - Specific installation instructions
# - **CPU Manufacturer Documentation** - Intel ARK or AMD specs
# - **Cooler Manual** - Mounting and thermal paste application
# - **BIOS Manual** - Configuration options and settings
#
# ---
#
# ## **Can I Help You With:**
#
# **Do you need:**
# - ✅ Specific CPU model compatibility information?
# - ✅ Motherboard specifications for your build?
# - ✅ Thermal paste application techniques?
# - ✅ Troubleshooting a specific CPU installation issue?
# - ✅ BIOS configuration help?
# - ✅ Recommendations for your programming laptop upgrade?
#
# Since you're looking for a laptop under $1200 with 16GB RAM for programming, upgrading an existing desktop CPU might be a consideration! Let me know if you need more detailed information about any particular aspect of CPU installation! 💻Perfect! Let me provide you with comprehensive technical documentation on CPU installation:
#
# ## **CPU Installation - Detailed Technical Guide**
#
# ### **Pre-Installation Requirements:**
#
# #### **1. Compatibility Check**
# - **Socket Type** - Verify your motherboard socket matches the CPU socket:
#   - **Intel:** LGA1700, LGA1851, LGA1200, etc.
#   - **AMD:** AM5, AM4, etc.
# - **Power Requirements** - Ensure your PSU has sufficient wattage for the new CPU
# - **BIOS Compatibility** - Check if your motherboard BIOS supports the new CPU
# - **Thermal Solution** - Verify your cooler is compatible with your socket type
#
# #### **2. Tools & Materials Needed**
# - Anti-static wrist strap
# - Thermal paste (Arctic MX-6, Noctua NT-H2, or equivalent)
# - CPU cooler (compatible with your socket)
# - Screwdriver (usually Phillips head PH2)
# - Isopropyl alcohol (for cleaning)
# - Lint-free cloth or coffee filters
# - Thermal paste spreader (plastic card or included tool)
#
# ---
#
# ## **Step-by-Step Installation Process:**
#
# ### **Step 1: Power Down & Safety**
# - Shut down your computer completely
# - Unplug the power cable from the PSU
# - Wait 5 minutes for residual power to dissipate
# - Put on anti-static wrist strap connected to case
# - Ground yourself by touching a metal part of the case
#
# ### **Step 2: Remove Old CPU (if applicable)**
# - Remove the CPU cooler (follow cooler-specific instructions)
# - Locate the CPU socket retention mechanism
# - Carefully lift the retention arm/lever
# - Gently remove the old CPU
# - Clean the socket with compressed air
# - Wipe socket clean with lint-free cloth
#
# ### **Step 3: Prepare the Socket**
# - Inspect the socket for bent pins or damage
# - Clean any dust or debris with compressed air
# - Ensure the socket is completely dry
# - Verify socket is in correct position for new CPU
#
# ### **Step 4: Install New CPU**
#
# #### **Alignment & Orientation:**
# - **Look for alignment markers:**
#   - Usually triangles or notches on CPU and socket
#   - Match CPU markers with socket markers
#   - Ensure proper orientation before insertion
#
# #### **Gentle Placement:**
# - Carefully place CPU into socket without forcing
# - CPU should slide in smoothly with minimal pressure
# - **Never force the CPU** - if it doesn't fit easily, check alignment
# - Lower retention arm/lever gently until it clicks
#
# #### **Socket-Specific Instructions:**
#
# **For Intel (LGA1700/LGA1851):**
# - Lift retention frame
# - Place CPU with notches aligned
# - Lower retention frame and secure
#
# **For AMD (AM5/AM4):**
# - Lift retention lever
# - Place CPU with notches aligned
# - Lower retention lever until it locks
# - Ensure CPU sits flush in socket
#
# ### **Step 5: Apply Thermal Paste**
#
# #### **Amount & Application:**
# - **Pea-sized amount:** Small dot in center of CPU IHS (Integrated Heat Spreader)
# - **Alternative method:** Small line across center
# - **Avoid excess:** Too much paste reduces cooling efficiency
# - **Coverage:** Let cooler spread it or use plastic spreader for even coverage
#
# #### **Thermal Paste Types:**
# - Arctic MX-6 (recommended)
# - Noctua NT-H2
# - Thermal Grizzly Kryonaut
# - Stock paste on cooler (if pre-applied)
#
# #### **Application Technique:**
# - Place small amount on CPU center
# - Use plastic spreader to spread evenly
# - Ensure entire IHS is covered
# - Avoid getting paste on socket or surrounding areas
#
# ### **Step 6: Install CPU Cooler**
#
# #### **Mounting Instructions:**
# - Follow your specific cooler's installation manual
# - **For Socket-Specific Coolers:**
#   - **Intel:** Use Intel mounting brackets (LGA1700/LGA1851)
#   - **AMD:** Use AMD mounting brackets (AM5/AM4)
# - Ensure proper mounting pressure (not too tight, not too loose)
# - Verify cooler makes full contact with CPU
# - Secure all mounting brackets and fasteners
#
# #### **Cooler Types:**
# - **Air Coolers:** Screw-down mounting
# - **Liquid Coolers (AIO):** Bracket mounting with pump head
# - **Stock Coolers:** Clip-on mounting
#
# ### **Step 7: Reconnect Power & Boot**
# - Reconnect all power cables:
#   - 24-pin ATX power
#   - 8-pin CPU power (4+4 pin)
# - Power on the system
# - Enter BIOS during startup (usually Delete, F2, or F12)
# - Verify CPU is recognized with correct specifications
#
# ---
#
# ## **BIOS Configuration After Installation:**
#
# ### **Important BIOS Steps:**
#
# #### **1. CPU Recognition**
# - Confirm new CPU is detected
# - Verify CPU name and speed
# - Check core count matches specifications
#
# #### **2. Voltage Settings**
# - Set CPU voltage to **AUTO** (recommended)
# - Do not manually adjust unless overclocking
# - Verify voltage is within safe range
#
# #### **3. XMP/DOCP Settings**
# - Re-enable if you have overclocking profiles
# - **Intel:** Intel XMP (Extreme Memory Profile)
# - **AMD:** AMD DOCP (Direct Overclocking Profile)
#
# #### **4. Temperature Monitoring**
# - Check CPU temperatures are normal
# - Monitor during boot and operation
# - Verify cooler is functioning properly
#
# #### **5. fTPM Reset (if needed)**
# - If you see "fTPM/PSP NV Corrupted" error:
#   - Enter BIOS setup
#   - Find fTPM option
#   - Select "Reset fTPM"
#   - Save and exit
#
# #### **6. Update BIOS (if needed)**
# - Check for BIOS updates for new CPU support
# - Download latest BIOS from motherboard manufacturer
# - Follow manufacturer's update procedure
# - Ensure stable power during update
#
# ---
#
# ## **Temperature Guidelines:**
#
# | Temperature Range | Status | Action |
# |------------------|--------|--------|
# | 30-50°C (Idle) | Normal | ✅ OK |
# | 50-70°C (Load) | Normal | ✅ OK |
# | 70-85°C (Heavy Load) | Acceptable | ✅ OK |
# | 85-95°C | Concerning | ⚠️ Monitor |
# | 95°C+ | Critical | ❌ Shut down |
# | 100°C+ | Dangerous | ❌ Immediate shutdown |
#
# ---
#
# ## **Post-Installation Verification:**
#
# ### **1. Run System Tests**
# - Boot into Windows/Linux normally
# - Check Device Manager for CPU recognition
# - Run CPU-Z or similar tool to verify specs
# - Verify CPU name, cores, threads, and speed
#
# ### **2. Monitor Temperatures**
# - Use HWInfo64 or similar monitoring software
# - Run stress tests:
#   - Prime95 (CPU intensive)
#   - MemTest86 (memory test)
#   - Cinebench (performance benchmark)
# - Verify temperatures stay within safe ranges
#
# ### **3. Check Performance**
# - Run benchmarks to verify performance
# - Monitor for thermal throttling
# - Ensure system stability during extended use
# - Check for any error messages
#
# ### **4. Verify Stability**
# - Run system for 30+ minutes under load
# - Monitor temperatures and clock speeds
# - Check for crashes or freezes
# - Verify all cores are recognized
#
# ---
#
# ## **Common Issues & Solutions:**
#
# | Issue | Cause | Solution |
# |-------|-------|----------|
# | CPU not recognized | Improper seating, BIOS outdated | Reseat CPU, update BIOS |
# | High temperatures | Poor thermal paste contact | Reapply thermal paste, check cooler contact |
# | System won't boot | Socket misalignment, power issues | Verify socket alignment, check power connections |
# | Thermal throttling | Inadequate cooling | Improve case airflow, reapply paste, upgrade cooler |
# | fTPM error | TPM firmware issue | Reset fTPM in BIOS |
# | BSOD errors | Driver incompatibility | Update chipset drivers, update BIOS |
# | Slow performance | Thermal throttling, BIOS settings | Check temps, verify clock speeds in BIOS |
#
# ---
#
# ## **Safety Warnings:**
#
# ⚠️ **Critical Precautions:**
# - ✅ Always use anti-static protection
# - ✅ Never force the CPU into the socket
# - ✅ Don't touch the CPU pins or socket pins
# - ✅ Ensure system is completely powered down before installation
# - ✅ Allow adequate cooling time before stress testing
# - ✅ Never apply excessive thermal paste
# - ✅ Verify socket type before purchasing CPU
# - ✅ Check motherboard compatibility before installation
#
# ---
#
# ## **Socket-Specific Information:**
#
# ### **Intel Sockets:**
# - **LGA1700** - 12th/13th/14th Gen Core processors
# - **LGA1851** - Arrow Lake processors
# - **LGA1200** - 10th/11th Gen Core processors
#
# ### **AMD Sockets:**
# - **AM5** - Ryzen 7000/8000/9000 series
# - **AM4** - Ryzen 3000/5000 series
#
# ---
#
# ## **Recommended Resources:**
#
# - **Motherboard Manual** - Specific installation instructions
# - **CPU Manufacturer Documentation** - Intel ARK or AMD specs
# - **Cooler Manual** - Mounting and thermal paste application
# - **BIOS Manual** - Configuration options and settings
#
# ---
#
# ## **Can I Help You With:**
#
# **Do you need:**
# - ✅ Specific CPU model compatibility information?
# - ✅ Motherboard specifications for your build?
# - ✅ Thermal paste application techniques?
# - ✅ Troubleshooting a specific CPU installation issue?
# - ✅ BIOS configuration help?
# - ✅ Recommendations for your programming laptop upgrade?
#
# Since you're looking for a laptop under $1200 with 16GB RAM for programming, upgrading an existing desktop CPU might be a consideration! Let me know if you need more detailed information about any particular aspect of CPU installation! 💻
#
# --------------------------------------------------
# \n✅ Basic testing completed!

# %%
response = create_agent("What is the specs of the laptop you are selling?")
# Out:
# Let me get the detailed specifications for the laptops we're currently selling.
# Tool #1: get_product_info
# Great question! Here are the laptop specifications we're currently offering:
#
# ## **Laptop Specifications:**
#
# ### **Processor Options:**
# - **Intel Processors** - Latest generation Core i5, i7, i9
# - **AMD Processors** - Ryzen 5, 7, 9 series
#
# ### **Memory & Storage:**
# - **RAM:** 8GB, 16GB, 24GB, 32GB options
# - **Storage:** SSD drives (various capacities)
# - **Expandability:** Varies by model
#
# ### **Display:**
# - **Sizes:** Various screen sizes available
# - **Resolution:** Full HD and higher options
# - **Refresh Rate:** Standard and high-refresh options
#
# ### **Connectivity:**
# - **USB-C/Thunderbolt** - Fast data transfer and charging
# - **Wi-Fi 6** - Latest wireless standard
# - **Bluetooth 5.0** - Stable wireless connections
# - **Multiple USB ports** - Legacy and modern connectivity
#
# ### **Key Features:**
# - ⌨️ **Backlit Keyboards** - For low-light environments
# - 🔋 **Long Battery Life** - Varies by model
# - 🔒 **Biometric Security** - Fingerprint/facial recognition options
# - 🎮 **Graphics Options** - Integrated or dedicated GPUs
#
# ### **Operating System Support:**
# - **Windows 11** - Full support
# - **macOS** - MacBook models
# - **Linux** - Support varies by model
#
# ### **Warranty & Support:**
# - **Warranty:** 1-year manufacturer warranty
# - **Extended Coverage:** Optional extended warranty available
# - **Technical Support:** Included
# - **Driver Updates:** Provided
#
# ---
#
# ## **Based on Your Profile - ThinkPad Recommendation:**
#
# Since I see you're interested in **ThinkPad models** and need a laptop for **programming with Linux compatibility**, here's what I recommend:
#
# ### **ThinkPad Series We Carry:**
# - **ThinkPad T-Series** - Professional workstations
# - **ThinkPad L-Series** - Value-oriented business laptops
# - **ThinkPad X-Series** - Ultraportable models
#
# **ThinkPads are excellent for:**
# ✅ Linux compatibility (excellent driver support)
# ✅ Durable build quality
# ✅ Great keyboards for programming
# ✅ Good thermal management
# ✅ Professional support
#
# ---
#
# ## **To Help You Find the Perfect Laptop:**
#
# Could you tell me:
#
# 1. **Budget Range?** (You mentioned under $1200 for programming)
# 2. **Specific Use Case?** (Web development, data science, systems programming, etc.)
# 3. **Preferred Processor?** (Intel or AMD?)
# 4. **RAM Requirement?** (You mentioned 16GB minimum)
# 5. **Linux Distribution?** (Ubuntu, Fedora, Arch, etc.?)
# 6. **Screen Size Preference?** (13", 14", 15", 17"?)
# 7. **Portability vs Performance?** (Ultrabook or workstation?)
#
# **Would you like me to:**
# - Search for specific ThinkPad models with Linux compatibility?
# - Compare different laptop models for programming?
# - Check warranty and support options?
# - Get information about return policies for laptops?
#
# I'm here to help you find the perfect programming laptop! 💻

# %% [markdown]
# ### Congratulations! 🎉
#
#
# You have successfully completed Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# What You Accomplished:
#
# ##### Tool Centralization & Reusability:
#
# - Migrated web search from local tool to centralized AgentCore Gateway
# - Integrated existing enterprise Lambda functions (warranty check, customer profile)
# - Created a shared tool infrastructure that multiple agent types can access
#
# ##### Enterprise-Grade Security:
#
# - Implemented JWT-based authentication with Cognito integration
# - Configured secure inbound authorization for gateway access
# - Established identity-based access control for tool usage
#
# ##### Scalable Architecture Foundation:
#
# - Built reusable tools that serve multiple use cases (customer support, sales, returns processing)
# - Eliminated code duplication across different agents
# - Created centralized management for tool updates and maintenance
#
# ##### Current Limitations (We'll fix these next!):
#
# - **Local Development Environment** - Still running on your laptop, not production-ready
# - **Limited Observability** - No comprehensive monitoring of agent behavior and performance
# - **Manual Scaling** - Cannot automatically handle increased load or multiple concurrent users
#
# ##### Next Up: Lab 4 - Deploying to Production with AgentCore Runtime
#
# In Lab 4, you'll transform your prototype into a production-ready system with:
#
# - AgentCore Runtime for scalable agent deployment
# - Comprehensive observability with metrics, logging, and tracing
# - Auto-scaling capabilities to handle real-world traffic
#
# ### Resources
# - [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html)
# - [Strands Agents Documentation](https://github.com/strands-agents/sdk-python)
# - [Official Customer Support Sample](https://github.com/awslabs/amazon-bedrock-agentcore-samples/tree/main/02-use-cases/customer-support-assistant)
